# %% [markdown]
# # Zomato Data Analysis Using Python

# %% [markdown]
# # Step 1 - Import necessary python libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Step 2 - create the data frame

# %%
dataframe = pd.read_csv("C:\\Users\\Raj Upadhyay\\OneDrive\\Desktop\\resume projects\\Zomato Data Analysis\\Zomato data .csv")
print(dataframe.head())
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
dataframe = pd.read_csv("C:\\Users\\Raj Upadhyay\\OneDrive\\Desktop\\resume projects\\Zomato Data Analysis\\Zomato data .csv")

# %%
dataframe
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %% [markdown]
# let's convert the data type of the "rate" column to float and remove the denominator

# %%
def handleRate(value):
    value=str(value).split('/')
    value=value[0];
    return float(value)

dataframe['rate']=dataframe['rate'].apply(handleRate)
print(dataframe.head())
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %% [markdown]
# # summary of the dataframe

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %% [markdown]
# # conclusion - there is no null values in dataframe

# %% [markdown]
# # type of Restaurant

# %%
sns.countplot(x=dataframe['listed_in(type)'])
plt.xlabel("Type of Restaurant")
# Out:
# Text(0.5, 0, 'Type of Restaurant')

# %% [markdown]
# # conclusion - the majority of the restaurents fall into the dining category
#
# Dining restaurents are prefered by a larger number of individuals

# %%
grouped_data = dataframe.groupby('listed_in(type)')['votes'].sum()
result = pd.DataFrame({'votes':grouped_data})
plt.plot(result,c="green" , marker='o')
plt.xlabel("Type of Restaurent" , c="red" , size=20)
plt.ylabel("Votes" , c="red" , size=20)
# Out:
# Text(0, 0.5, 'Votes')

# %% [markdown]
# # The majority of Restaurents received ratings

# %%
plt.hist(dataframe['rate'],bins=5)
plt.title("Rating Distribution")
plt.show()

# %% [markdown]
# # conclusion - The majority of Restaurents received ratings ranging from 3.5 to 4

# %% [markdown]
# # The majority of couples prefer restaurents with an approximate cost of 300 Rupees.

# %%
couple_data = dataframe['approx_cost(for two people)']
sns.countplot(x=couple_data)
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %% [markdown]
# # whether online orders receive higher ratings than offline orders.

# %%
plt.figure(figsize = (6,6))
sns.boxplot(x = 'online_order' , y = 'rate' , data = dataframe)
# Out:
# <Axes: xlabel='online_order', ylabel='rate'>

# %% [markdown]
# # CONCLUSION - Offline orders received lower ratings in comparision to online orders , which obtained excellent ratings.

# %%
pivot_table = dataframe.pivot_table(index='listed_in(type)', columns='online_order', aggfunc='size', fill_value=0)
sns.heatmap(pivot_table, annot=True, cmap="YlGnBu", fmt='d')
plt.title("Heatmap")
plt.xlabel("Online Order")
plt.ylabel("Listed In (Type)")
plt.show()

# %% [markdown]
# # CONCLUSION - Dining restaurents primarily accept offline orders , Whereas cafes primarily receive online orders.This suggests that clients prefer to place orders in person at restaurents , But prefer online ordering at cafes.
